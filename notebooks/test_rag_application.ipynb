# %%
from app.applications.rag_service import RagService


rag_service = RagService(top_k=5)

result = rag_service.answer(
    question="What's the the first step to become an GenAI engineer?",
    collection_name="notebook_test"
)

print(result)
# Out:
# {'answer': 'The first step to become an AI engineer is to start with OpenAI.', 'sources': [{'chunk_id': 'YouTube: O2UmHpNlwUw-chunk-0', 'metadata': {'chunk_index': 0, 'language': 'en', 'video_id': 'O2UmHpNlwUw', 'source_type': 'youtube', 'is_generated': True, 'video_url': 'https://www.youtube.com/watch?v=O2UmHpNlwUw', 'duration_seconds': 1170.32, 'source': 'YouTube: O2UmHpNlwUw', 'end_time': 65.199, 'start_time': 0.08, 'total_chars': 21180, 'segment_count': 558}}, {'chunk_id': 'YouTube: O2UmHpNlwUw-chunk-3', 'metadata': {'start_time': 216.799, 'language': 'en', 'segment_count': 558, 'total_chars': 21180, 'video_url': 'https://www.youtube.com/watch?v=O2UmHpNlwUw', 'duration_seconds': 1170.32, 'end_time': 295.199, 'is_generated': True, 'video_id': 'O2UmHpNlwUw', 'source_type': 'youtube', 'source': 'YouTube: O2UmHpNlwUw', 'chunk_index': 3}}, {'chunk_id': 'YouTube: O2UmHpNlwUw-chunk-2', 'metadata': {'is_generated': True, 'duration_seconds': 1170.32, 'source_type': 'youtube', 'video_url':
# ...
